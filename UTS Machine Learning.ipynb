# %% [markdown]
# 1.  Jelaskan apa yang dimaksud dengan Machine Learning

# %% [markdown]
# Jawab : Machine learning adalah ilmu pengembangan algoritma dan model secara statistik yang digunakan sistem komputer untuk menjalankan tugas tanpa instruksi eksplisit, mengandalkan pola serta inferensi sebagai gantinya.

# %% [markdown]
# 2. Berikan contoh penerapan implemetasi dalam kehidupan sehari-hari terkait Machine Learning. Dan
# jelaskan mengapa membutuhkannya dan manfaatnya

# %% [markdown]
# Jawab : Contoh: Aplikasi navigasi seperti Google Maps dan layanan transportasi seperti Uber dan Gojek.
# Alasan: Membantu pengguna menemukan rute tercepat dan paling efisien, serta memprediksi waktu kedatangan.
# Manfaat: Menghemat waktu dan bahan bakar, serta meningkatkan efisiensi perjalanan.

# %% [markdown]
# 3.  Jelaskan macam-macam taxonomi dalam pengerapan Machine Learning

# %% [markdown]
# Jawab  : Berdasarkan Jenis Pembelajaran
# •	Pembelajaran Terawasi (Supervised Learning): Algoritma dilatih menggunakan data yang diberi label. Contoh: regresi linear, pohon keputusan, SVM.
# Klasifikasi: Memprediksi kategori/discrete output (contoh: email spam atau tidak).
# Regresi: Memprediksi nilai kontinu (contoh: harga rumah).
# •	Pembelajaran Tak Terawasi (Unsupervised Learning): Algoritma dilatih menggunakan data yang tidak diberi label. Contoh: klustering, asosiasi.
# Klustering: Mengelompokkan data ke dalam grup (contoh: k-means).
# Asosiasi: Menemukan aturan yang menggambarkan data (contoh: algoritma apriori).
# Berdasarkan Teknik
# •	Algoritma Linear: Mengasumsikan hubungan linear antara input dan output. Contoh: regresi linear.
# •	Algoritma Non-Linear: Mengasumsikan hubungan non-linear antara input dan output. Contoh: pohon keputusan, neural networks.
# Berdasarkan Komputasi
# •	Algoritma Probabilistik: Menggunakan teori probabilitas untuk membuat prediksi. Contoh: Naive Bayes.
# •	Algoritma Deterministik: Menghasilkan output yang sama untuk input yang sama. Contoh: pohon keputusan.
# Berdasarkan Struktur Data
# •	Pembelajaran Berbasis Batching (Batch Learning): Algoritma dilatih menggunakan seluruh dataset sekaligus.
# •	Pembelajaran Berbasis Online (Online Learning): Algoritma dilatih menggunakan data secara berkelanjutan.

# %% [markdown]
# A. Berapa rata-rata mahasiswa datang pada minggu ini?

# %% [markdown]
# Jawab : (2+3+4+1+2+5+2) / 5 = 3,8

# %% [markdown]
# B. Kapan biaya tertinggi terjadi?

# %% [markdown]
# Jawab : Biaya Tertinggi Hari sabtu = Datang (5) x biaya (30.000) = 150.000

# %% [markdown]
# C. Hari apa biaya lebih dari 110000?

# %% [markdown]
# Jawab : Hari Sabtu dikarenakan datang x biaya = 5 x 30.000 = 150.000

# %% [markdown]
# D. Siapa yang paling banyak datang ke kampus?

# %% [markdown]
# Jawab : Ani total 7 kali datang

# %% [markdown]
# E. Siapa yang datang pada hari minggu?

# %% [markdown]
# Jawab : yang datang di hari minggu adalah budi

# %% [markdown]
# F. Berapa biaya tertinggi dan terendah?

# %% [markdown]
# Jawab : Biaya tertinggi Ani dengan 150.000 + 60.000 = 210.000
# 	Biaya terendah Lono dengan 15.000

# %% [markdown]
# G. Berapa frekuensi datang tertinggi dan terendah?

# %% [markdown]
# Jawab : Frekuensi kedatangan tertinggi adalah Ani dengan 7 kali datang
# 	Frekuensi kedatangan terendah adalah Lono dengan 1 kali datang

# %%
import matplotlib.pyplot as plt

fakultas = ["Bisnis", "D3 Perhotelan", "ICT", "Ilmu Komunikasi", "Seni dan Desain"]
jumlah_mahasiswa = [260, 28, 284, 465, 735]

plt.figure(figsize=(10, 6))
plt.bar(fakultas, jumlah_mahasiswa, color='skyblue')
plt.xlabel('Fakultas')
plt.ylabel('Jumlah Mahasiswa')
plt.title('Jumlah Mahasiswa per Fakultas')
plt.xticks(rotation=45)
plt.tight_layout()

plt.show()
